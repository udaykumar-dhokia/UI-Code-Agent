# %% [markdown]
# Required Dependencies

# %%
# %%writefile requirements.txt
# streamlit
# langchain
# langchain-google-genai
# langchain_community
# crewai
# python-dotenv
# google-generativeai
# Pillow
# Out:
# Overwriting requirements.txt

# %%
! pip install streamlit langchain_google_genai crewai python-dotenv pillow requests beautifulsoup4 google-generativeai
# Out:
# Requirement already satisfied: streamlit in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (1.42.0)
# Requirement already satisfied: langchain_google_genai in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (1.0.4)
# Requirement already satisfied: crewai in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (0.30.11)
# Requirement already satisfied: python-dotenv in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (1.0.1)
# Requirement already satisfied: pillow in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (10.3.0)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (2.32.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (4.12.3)
# Requirement already satisfied: google-generativeai in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (0.5.4)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from streamlit) (4.12.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\admin\appdata\roaming\python\python311\site-packages (from streamlit) (6.4)
# Requirement already satisfied: langchain-core<0.3,>=0.1.45 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain_google_genai) (0.1.52)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.98 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.1.102)
# Requirement already satisfied: instructor<0.6.0,>=0.5.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.5.2)
# Requirement already satisfied: langchain<0.2.0,>=0.1.10 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.1.20)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.30.3)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.24.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2.7.1)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2023.12.25)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai) (0.6.4)
# Requirement already satisfied: google-api-core in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai) (2.19.0)
# Requirement already satisfied: google-api-python-client in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai) (2.130.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai) (2.29.0)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-ai-generativelanguage==0.6.4->google-generativeai) (1.23.0)
# Requirement already satisfied: jinja2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (1.26.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (1.13.1)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.4.24)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (1.52.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.1.43)
# Requirement already satisfied: langchain-openai<0.0.6,>=0.0.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.0.5)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (3.5.0)
# Requirement already satisfied: pypdf<4.0.0,>=3.11.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (3.17.4)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (2.0.30)
# Requirement already satisfied: tiktoken<0.6.0,>=0.5.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai) (0.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-core->google-generativeai) (1.63.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from instructor<0.6.0,>=0.5.2->crewai) (3.9.5)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from instructor<0.6.0,>=0.5.2->crewai) (0.15)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from instructor<0.6.0,>=0.5.2->crewai) (0.9.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain<0.2.0,>=0.1.10->crewai) (6.0.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.6.6)
# Requirement already satisfied: langchain-community<0.1,>=0.0.38 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.0.38)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain<0.2.0,>=0.1.10->crewai) (0.1.63)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.3,>=0.1.45->langchain_google_genai) (1.33)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (7.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai) (0.45b0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.4.2->crewai) (2.18.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (1.9.4)
# Requirement already satisfied: Mako in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai) (1.3.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.110.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.30.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.18.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.45b0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.64.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (4.1.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.10.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai) (0.9.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai) (1.62.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.16.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (3.23.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.0.4)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai) (3.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.45->langchain_google_genai) (2.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain<0.2.0,>=0.1.98->crewai) (3.0.3)
# Requirement already satisfied: pyproject_hooks in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.1.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.37.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai) (1.5.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.2.2)
# Requirement already satisfied: coloredlogs in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (24.3.25)
# Requirement already satisfied: sympy in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.12)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (65.5.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.8.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.23.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (12.0)
# Requirement already satisfied: filelock in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (2024.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai) (3.4.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Installation of required libraries

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: streamlit in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 1)) (1.42.0)
# Requirement already satisfied: langchain in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 2)) (0.1.20)
# Requirement already satisfied: langchain-google-genai in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 3)) (1.0.4)
# Requirement already satisfied: langchain_community in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 4)) (0.0.38)
# Requirement already satisfied: crewai in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 5)) (0.30.11)
# Requirement already satisfied: python-dotenv in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: google-generativeai in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: Pillow in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 8)) (10.3.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (2.32.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (13.7.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from streamlit->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\admin\appdata\roaming\python\python311\site-packages (from streamlit->-r requirements.txt (line 1)) (6.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (0.6.6)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.52 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (0.1.63)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (2.7.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.98 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai->-r requirements.txt (line 5)) (0.1.102)
# Requirement already satisfied: instructor<0.6.0,>=0.5.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai->-r requirements.txt (line 5)) (0.5.2)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai->-r requirements.txt (line 5)) (1.30.3)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai->-r requirements.txt (line 5)) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai->-r requirements.txt (line 5)) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai->-r requirements.txt (line 5)) (1.24.0)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from crewai->-r requirements.txt (line 5)) (2023.12.25)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai->-r requirements.txt (line 7)) (0.6.4)
# Requirement already satisfied: google-api-core in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai->-r requirements.txt (line 7)) (2.19.0)
# Requirement already satisfied: google-api-python-client in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai->-r requirements.txt (line 7)) (2.130.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai->-r requirements.txt (line 7)) (2.29.0)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-generativeai->-r requirements.txt (line 7)) (4.66.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-ai-generativelanguage==0.6.4->google-generativeai->-r requirements.txt (line 7)) (1.23.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.9.4)
# Requirement already satisfied: jinja2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (1.26.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 2)) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.4.24)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.52.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.1.43)
# Requirement already satisfied: langchain-openai<0.0.6,>=0.0.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.0.5)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: pypdf<4.0.0,>=3.11.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (3.17.4)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.7.7)
# Requirement already satisfied: tiktoken<0.6.0,>=0.5.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-core->google-generativeai->-r requirements.txt (line 7)) (1.63.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 7)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 7)) (4.9)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from instructor<0.6.0,>=0.5.2->crewai->-r requirements.txt (line 5)) (0.15)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from instructor<0.6.0,>=0.5.2->crewai->-r requirements.txt (line 5)) (0.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.2.0,>=0.1.52->langchain->-r requirements.txt (line 2)) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain->-r requirements.txt (line 2)) (3.10.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai->-r requirements.txt (line 5)) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai->-r requirements.txt (line 5)) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai->-r requirements.txt (line 5)) (7.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai->-r requirements.txt (line 5)) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai->-r requirements.txt (line 5)) (1.24.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai->-r requirements.txt (line 5)) (0.45b0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 2)) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 7)) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 7)) (4.1.1)
# Requirement already satisfied: Mako in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.3.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (2.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.110.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.30.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.18.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.45b0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.64.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (4.1.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai->-r requirements.txt (line 7)) (1.62.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (2.16.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (3.23.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai->-r requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai->-r requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai->-r requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai->-r requirements.txt (line 5)) (3.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain->-r requirements.txt (line 2)) (2.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: pyproject_hooks in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.37.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (3.2.2)
# Requirement already satisfied: coloredlogs in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (24.3.25)
# Requirement already satisfied: sympy in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.12)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (65.5.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.23.2)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (12.0)
# Requirement already satisfied: filelock in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (2024.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.17->embedchain<0.2.0,>=0.1.98->crewai->-r requirements.txt (line 5)) (3.4.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile .env
# GOOGLE_API_KEY = "YOUR GOOGLE_API_KEY"
# Out:
# Overwriting .env

# %%
# %%writefile UI_Code_Agent.py

import os
import streamlit as st
import pathlib
from PIL import Image
from dotenv import load_dotenv
import google.generativeai as genai
load_dotenv()

# Configure the API key directly in the script
API_KEY = os.environ.get("GOOGLE_API_KEY")
genai.configure(api_key=API_KEY)

# Generation configuration
generation_config = {
    "temperature": 0.8,
    "top_p": 0.95,
    "top_k": 64,
    "max_output_tokens": 50000,
    "response_mime_type": "text/plain",
}

# Safety settings
safety_settings = [
    {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_NONE"},
    {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_NONE"},
    {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_NONE"},
    {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_NONE"},
]

# Model name
MODEL_NAME = "gemini-1.5-flash-latest"

# Framework selection (e.g., Tailwind, Bootstrap, etc.)
framework = "Regular CSS use flex grid etc"  # Change this to "Bootstrap" or any other framework as needed

# Create the model
model = genai.GenerativeModel(
    model_name=MODEL_NAME,
    safety_settings=safety_settings,
    generation_config=generation_config,
)

# Start a chat session
chat_session = model.start_chat(history=[])

# Function to send a message to the model
def send_message_to_model(message, image_path):
    image_input = {
        'mime_type': 'image/jpeg',
        'data': pathlib.Path(image_path).read_bytes()
    }
    response = chat_session.send_message([message, image_input])
    return response.text

# Streamlit app
def main():
    st.title("Gemini 1.5 Flash, UI to Code 👨‍💻 ")
    st.subheader("Transforming your UI snapshots into code, because typing is so last decade! 🚀📸➡️💻")

    uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "jpeg", "png"])

    if uploaded_file is not None:
        try:
            # Load and display the image
            image = Image.open(uploaded_file)
            st.image(image, caption='Uploaded Image.', use_column_width=True)

            # Convert image to RGB mode if it has an alpha channel
            if image.mode == 'RGBA':
                image = image.convert('RGB')

            # Save the uploaded image temporarily
            temp_image_path = pathlib.Path("temp_image.jpg")
            image.save(temp_image_path, format="JPEG")

            # Generate UI description
            if st.button("Code UI"):
                st.write("🧑‍💻 Looking at your UI...")
                prompt = "Describe this UI in accurate details. When you reference a UI element put its name and bounding box in the format: [object name (y_min, x_min, y_max, x_max)]. Also Describe the color of the elements."
                description = send_message_to_model(prompt, temp_image_path)
                st.write(description)

                # Refine the description
                st.write("🔍 Refining description with visual comparison...")
                refine_prompt = f"Compare the described UI elements with the provided image and identify any missing elements or inaccuracies. Also Describe the color of the elements. Provide a refined and accurate description of the UI elements based on this comparison. Here is the initial description: {description}"
                refined_description = send_message_to_model(refine_prompt, temp_image_path)
                st.write(refined_description)

                # Generate HTML
                st.write("🛠️ Generating website...")
                html_prompt = f"Create an HTML file based on the following UI description, using the UI elements described in the previous response. Include {framework} CSS within the HTML file to style the elements. Make sure the colors used are the same as the original UI. The UI needs to be responsive and mobile-first, matching the original UI as closely as possible. Do not include any explanations or comments. Avoid using ```html. and ``` at the end. ONLY return the HTML code with inline CSS. Here is the refined description: {refined_description}"
                initial_html = send_message_to_model(html_prompt, temp_image_path)
                st.code(initial_html, language='html')

                # Refine HTML
                st.write("🔧 Refining website...")
                refine_html_prompt = f"Validate the following HTML code based on the UI description and image and provide a refined version of the HTML code with {framework} CSS that improves accuracy, responsiveness, and adherence to the original design. ONLY return the refined HTML code with inline CSS. Avoid using ```html. and ``` at the end. Here is the initial HTML: {initial_html}"
                refined_html = send_message_to_model(refine_html_prompt, temp_image_path)
                st.code(refined_html, language='html')

                # Save the refined HTML to a file
                with open("index.html", "w") as file:
                    file.write(refined_html)
                st.success("HTML file 'index.html' has been created.")

                # Provide download link for HTML
                st.download_button(label="Download HTML", data=refined_html, file_name="index.html", mime="text/html")
        except Exception as e:
            st.error(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Overwriting UI_Code_Agent.py

# %% [markdown]
# Installation of localtunnel for remote tunnel server

# %%
! npm install localtunnel
# Out:
# up to date, audited 23 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.

# %%
! streamlit run UI_Code_Agent.py & npx localtunnel --port 8501
# Out:
# ^C
